# %% [markdown]
# # Author: Ashwin S

# %% [markdown]
# ## Task 3: Exploratory Data Analysis - Retail

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv(r"C:\Users\ashwi\OneDrive\Desktop\The Spark Foundation\SampleSuperstore.csv")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
w = df[df["Ship Mode"]=="First Class"]
x = df[df["Ship Mode"]=="Second Class"]
y = df[df["Ship Mode"]=="Standard Class"]
z = df[df["Ship Mode"]=="Same Day"]

# %%
n = np.array([np.average(w["Profit"]), np.average(x["Profit"]), np.average(y["Profit"]), np.average(z["Profit"])])
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = '#0018ed'
plt.rcParams['axes.labelcolor']= '#FFFF00'
plt.rcParams['xtick.color'] = '#FFFF00'
plt.rcParams['ytick.color'] = '#FFFF00'
plt.rcParams['font.size']=20
mylabels = ["First Class (31.83%)", "Second Class (29.53%)", "Standard Class (27.49%)", "Same Day (29.26%)"]
plt.figure(figsize=(20,10))
wp = { 'linewidth' : 1, 'edgecolor' : "white" } 
plt.pie(n, labels = mylabels, shadow = True, wedgeprops = wp, explode=(0.1, 0.1, 0.1, 0.1) )
plt.legend(title = "Average Sales: ", fontsize=15, facecolor="#b8a5b8", edgecolor="#ffffff", loc ="center right")
plt.show()

# %%
df["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df["Region"].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df1 = df[["Sales", "Quantity", "Discount", "Profit"]]
sns.set_style('darkgrid')
_ = sns.pairplot(df1,height=5)

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize':(100,8.27)})
_=sns.jointplot(data=df, x="Discount", y="Sales", hue="Category",height =15, s=100)

# %%
sns.set_style('darkgrid')
_ = sns.catplot(x ='Segment', y ='Profit', data = df, kind ='bar',height=10, aspect=12/10)

# %%
sns.set_style('darkgrid')
_ = sns.catplot(x ='Sub-Category', y ='Sales', data = df, kind ='bar',height=10, aspect=22.7/8.27)

# %%
sns.set_style('darkgrid')
_ = sns.catplot(x ='Region', y ='Sales', data = df, kind ='bar',height=10, aspect=12/10)

# %%
sns.set_style('darkgrid')
_ = sns.catplot(x ='Region', y ='Profit', data = df, kind ='bar',height=10, aspect=12/10)

# %%
lae=LabelEncoder()
df["Ship Mode"] = lae.fit_transform(df["Ship Mode"].astype(str))
df["Segment"] = lae.fit_transform(df["Segment"].astype(str))
df["City"] = lae.fit_transform(df["City"].astype(str))
df["State"] = lae.fit_transform(df["State"].astype(str))
df["Region"] = lae.fit_transform(df["Region"].astype(str))
df["Category"] = lae.fit_transform(df["Category"].astype(str))
df["Sub-Category"] = lae.fit_transform(df["Sub-Category"].astype(str))
corelation = df.corr()
plt.subplots(figsize=(20,15))
_ = sns.heatmap(corelation,xticklabels=corelation.columns, yticklabels=corelation.columns,annot=True)

# %% [markdown]
# From this we can understand:

# %% [markdown]
# In "Central" Region the profit and sales are less

# %% [markdown]
# Labels, Art, Paper, Fastners are sold less than the other products.

# %% [markdown]
# First class products are sold more than Second class, Standard class and Same day.
# So we should give discount more to other classes to increase the profit.

# %% [markdown]
# The Discount should not be more than 4% . When the Discount goes beyond 4 % the profit decreases . So we should try to keep the discount atmost 4 %.

# %% [markdown]
# Consumers gives less profit than other segment.
